# %% [markdown]
# # Data Collection: TMDB 5000 Movie Dataset
#
# This notebook downloads the TMDB 5000 Movie Dataset from Kaggle using the Kaggle API.

# %%
# Install the Kaggle package if it's not already installed
# !pip install -q kagglehub

# %%
import kagglehub
import pandas as pd
import os

# %%
# Download latest version
path = kagglehub.dataset_download("shubhammehta21/movie-lens-small-latest-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 971k/971k [00:00<00:00, 86.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/shubhammehta21/movie-lens-small-latest-dataset/versions/1

# %%
files = sorted(os.listdir(path))
files
# Out:
# ['README.txt', 'links.csv', 'movies.csv', 'ratings.csv', 'tags.csv']

# %%
movies = pd.read_csv(os.path.join(path, files[1]))
movies
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]
